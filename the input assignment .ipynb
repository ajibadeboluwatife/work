# %%
credit = input('how many credit hours do you do?')
credit_hours2 = input('are you instate?(yes or no)')
if credit == 'yes':
    tuition = int(credit * 296)
    print(tuition)
else:
    tuition2 = (credit * 1066)
    print(tuition2)
# Out:
# how many credit hours do you do?12
# are you instate?(yes or no)yes
# ...

# %%
credit = int(input('how many credit hours do you do?'))
credit_hours2 = str(input('are you instate?(yes or no)'))
if credit_hours2 == 'yes':
    tuition = int(credit * 296)
    print('your tuition as an in statue student is :' , tuition)
else:
    tuition2 = (credit * 1066)
    print('your tuition as an out of state student is ' ,tuition2)
# Out:
# how many credit hours do you do?12
# are you instate?(yes or no)no
# your tuition as an out of state student is  12792

# %%
type(credit)
# Out:
# int
